# %% [markdown]
# # Evaluate Your Model with Appropriate Metrics
#
# ## 📋 Overview
# In this activity, you'll learn to evaluate machine learning models using appropriate metrics for both classification and regression tasks. You'll develop skills to understand the strengths and limitations of various metrics, ensuring they align with business objectives. Evaluating models effectively is crucial for data scientists and machine learning engineers to draw actionable insights and guide model improvement.
#
# ## 🎯 Activity Goals
# By completing this activity, you will:
# - Select suitable evaluation metrics for classification and regression problems.
# - Justify the selection of metrics based on business objectives.
# - Analyze and compare model performance using these metrics.
#
# ## 🌎 Scenario
# Imagine you're part of a data science team at a company striving to enhance its product offering. Your task is to evaluate the predictive models that have been developed to forecast customer behavior. Whether it's predicting customer churn or estimating product demand, choosing the appropriate evaluation metrics is critical to aligning the model's performance with the company's strategic goals.

# %% [markdown]
# ## Step 1: Choose Your Model and Dataset
# Select a trained model from a previous task or start fresh with one of the module's predefined datasets (e.g., Telecom Customer Churn, Credit Card Fraud Detection). Ensure your choice aligns with a classification or regression task.
#
# <b>Reminder:</b> A number of dataset csv files have been uploaded to this lab environment. Choose one dataset from the following options:
# - Customer Churn (Telecom): `Telco-Customer-Churn.csv`
# - Credit Card Fraud Detection: `creditcard.csv`
# - Bike Sharing Demand Forecasting: `bikeshareday.csv`
# - IMDb Sentiment Analysis (NLP): `IMDB_Dataset.csv`
# - Customer Segmentation (Clustering): `marketing_campaign.csv`

# %%
# Load the dataset
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt 
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score,
    roc_auc_score, confusion_matrix, classification_report,
    average_precision_score, log_loss, matthews_corrcoef,
    roc_curve, precision_recall_curve
)

from sklearn.metrics import accuracy_score
from sklearn.model_selection import RandomizedSearchCV

import joblib

import warnings 
warnings.filterwarnings("ignore")
pd.set_option('display.max_columns', 10000)

# %%
# Your code here
# Load and prepare your data

# Your code here
df= pd.read_csv("creditcard.csv")

# Explore the data
print(f"Shape of Data: {df.shape}")
print("\n----- Top 5 Rows of Data ------")
display(df.head())
print("\n----- Information of Data ------")
print(df.info())
print("\n----- Summmary of Data ------")
display(df.describe(percentiles=[i/100 for i in range(0, 101) if i%5==0]).T)
print("\n------- Number of Null Values ---------")
print(df.isnull().sum())

print("Class Count:\n", df['Class'].value_counts(dropna=False))

print("Class distribution:\n", df['Class'].value_counts(dropna=False, normalize=True))
# Out:
# Shape of Data: (284807, 31)
#
# ----- Top 5 Rows of Data ------
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0  0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390 -0.311169
# 1  0.085102 -0.255425 -0.166974  1.612727  1.065235  0.489095 -0.143772
# 2  0.247676 -1.514654  0.207643  0.624501  0.066084  0.717293 -0.165946
# 3  0.377436 -1.387024 -0.054952 -0.226487  0.178228  0.507757 -0.287924
# 4 -0.270533  0.817739  0.753074 -0.822843  0.538196  1.345852 -1.119670
#
# ...

# %%
X = df.drop(columns=['Class'])  # Features
y = df['Class']                 # Target

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %% [markdown]
# <b>💡 Tip:</b> Consider the end goal when selecting a model or dataset. For instance, predicting customer churn typically requires a classification model.
# ### ❗ Common Mistakes
# - Selecting incompatible metrics for your model type.
# - Misaligning the choice of dataset with business needs.

# %% [markdown]
# ## Step 2: Select Evaluation Metrics
# Identify relevant metrics for your task:
# - <b>Classification:</b> Accuracy, Precision, Recall, F1-Score, ROC-AUC.
# - <b>Regression:</b> Mean Absolute Error (MAE), Root Mean Squared Error (RMSE), R-squared (R²).
#
# Justify your selection. How do these metrics serve your business objectives? For example, emphasizing recall may be crucial to avoid missed churning customers.

# %%
# Your code here

clf= XGBClassifier(
    subsample=0.6,
    reg_lambda=1.5,
    reg_alpha=0.01,
    n_estimators=200,
    max_depth=3,
    learning_rate=0.05,
    gamma=0.1,
    colsample_bytree=1.0,
    random_state=42,
    use_label_encoder=False,
    eval_metric='logloss'
)

clf.fit(X_train, y_train)

# Predictions 
y_pred = clf.predict(X_test) 
y_proba = clf.predict_proba(X_test)[:, 1]

# %% [markdown]
# <b>💡 Tip:</b> Prioritize metrics that reflect business implications, not just statistical measures.
# ### ❗ Common Mistakes
# - Ignoring the context of business objectives when choosing metrics.
# - Focusing only on metrics that show high performance but offer little business insight.

# %% [markdown]
# ## Step 3: Calculate and Compare Metrics
# Implement calculations for your selected metrics using Python libraries such as sklearn. Assess the results, examining any trade-offs between metrics. For example, high precision but low recall might indicate many false negatives.

# %%
# Your code here

# Basic metrics
acc = accuracy_score(y_test, y_pred)
prec = precision_score(y_test, y_pred)
rec = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
roc_auc = roc_auc_score(y_test, y_proba)
avg_prec = average_precision_score(y_test, y_proba)
logloss = log_loss(y_test, y_proba)
mcc = matthews_corrcoef(y_test, y_pred)

# Confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Display results
print(f"Accuracy: {acc:.4f}")
print(f"Precision: {prec:.4f}")
print(f"Recall: {rec:.4f}")
print(f"F1 Score: {f1:.4f}")
print(f"ROC-AUC: {roc_auc:.4f}")
print(f"Log Loss: {logloss:.4f}")
print(f"Average Precision (PR-AUC): {avg_prec:.4f}")
print(f"Matthews Corrcoef: {mcc:.4f}")
print("\nClassification Report:")
print(classification_report(y_test, y_pred))

# Confusion Matrix Plot
plt.figure(figsize=(6, 4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Legit', 'Fraud'], yticklabels=['Legit', 'Fraud'])
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.tight_layout()
plt.show()

# ROC Curve
fpr, tpr, _ = roc_curve(y_test, y_proba)
plt.figure(figsize=(6, 4))
plt.plot(fpr, tpr, label=f"ROC Curve (AUC = {roc_auc:.2f})")
plt.plot([0, 1], [0, 1], linestyle='--', color='gray')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve")
plt.legend()
plt.tight_layout()
plt.show()

# Precision-Recall Curve
precision, recall, _ = precision_recall_curve(y_test, y_proba)
plt.figure(figsize=(6, 4))
plt.plot(recall, precision, label=f"PR Curve (AP = {avg_prec:.2f})")
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title("Precision-Recall Curve")
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# Accuracy: 0.9996
# Precision: 0.9872
# Recall: 0.7857
# F1 Score: 0.8750
# ROC-AUC: 0.9833
# Log Loss: 0.0022
# Average Precision (PR-AUC): 0.8887
# Matthews Corrcoef: 0.8805
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.99      0.79      0.88        98
#
#     accuracy                           1.00     56962
#    macro avg       0.99      0.89      0.94     56962
# weighted avg       1.00      1.00      1.00     56962

# %% [markdown]
# <b>💡 Tip:</b> Use a confusion matrix to visualize and understand classification metric outcomes.
# ### ❗ Common Mistakes
# - Misinterpreting metric significance due to lack of context.
# - Overlooking negative implications of trade-offs between metrics.

# %% [markdown]
# ## Step 4: Reflect on Model Improvement
# Analyze how the metrics can guide future improvements in your model. Does the evaluation suggest overfitting, data imbalance, or inadequate feature representation? Plan actionable steps to address these issues.

# %%
# Your code here

print("REFLECTION:")
print("""
- Precision is important to avoid annoying legitimate customers with false fraud alerts.
- Recall is critical to catch actual fraud and minimize financial loss.
- The F1-score provides a balanced view, and ROC-AUC gives threshold-independent insight.

Improvement Strategies:
- Use SMOTE or undersampling to address class imbalance.
- Explore other classifiers like XGBoost or logistic regression with class_weight.
- Adjust the decision threshold for optimal trade-off based on business cost analysis.
""")
# Out:
# REFLECTION:
#
# - Precision is important to avoid annoying legitimate customers with false fraud alerts.
# - Recall is critical to catch actual fraud and minimize financial loss.
# - The F1-score provides a balanced view, and ROC-AUC gives threshold-independent insight.
#
# Improvement Strategies:
# - Use SMOTE or undersampling to address class imbalance.
# - Explore other classifiers like XGBoost or logistic regression with class_weight.
# - Adjust the decision threshold for optimal trade-off based on business cost analysis.

# %% [markdown]
# <b>💡 Tip:</b> Reviewing domain-specific literature or case studies can provide insights for model refinement.
# ### ❗ Common Mistakes
# - Not using metric insights to drive model iterations.
# - Failing to connect metric evaluation to potential enhancements.

# %% [markdown]
# ## ✅ Success Checklist
# - Appropriate selection of model and dataset
# - Justification for chosen metrics aligns with business objectives
# - Correct calculation and interpretation of selected metrics
# - Reflection provides actionable insights for model improvement
#
# ## 💡 Key Points
# - Understanding evaluation metrics is essential for aligning models with business goals.
# - Different metrics provide different insights; choose those that matter for your use case.
# - Model evaluation is an ongoing process, informing iterative improvements.

# %% [markdown]
# ## 📚 Exemplar Solution
# Below is an exemplar solution for the credit card fraud dataset.

# %% [markdown]
# <details>
#
# <summary><strong>Click HERE to see a reference solution</strong></summary>
#
# ```python
# # Step 1: Load the Dataset and Train a Model
#
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt
#
# from sklearn.model_selection import train_test_split
# from sklearn.ensemble import RandomForestClassifier
# from sklearn.preprocessing import StandardScaler
#
# # Load dataset
# df = pd.read_csv("creditcard.csv")
#
# # Drop rows with missing target
# df = df.dropna(subset=['Class'])
#
# # Features and target
# X = df.drop(columns=['Class'])
# y = df['Class']
#
# # Standardize the 'Amount' and 'Time' features
# scaler = StandardScaler()
# X[['Time', 'Amount']] = scaler.fit_transform(X[['Time', 'Amount']])
#
# # Train-test split (stratified to preserve fraud ratio)
# X_train, X_test, y_train, y_test = train_test_split(
#     X, y, test_size=0.3, stratify=y, random_state=42
# )
#
# # Train model
# clf = RandomForestClassifier(n_estimators=100, random_state=42, class_weight='balanced')
# clf.fit(X_train, y_train)
#
# # Predictions
# y_pred = clf.predict(X_test)
# y_proba = clf.predict_proba(X_test)[:, 1]
#
# """# Step 2: Select and Justify Evaluation Metrics"""
#
# print("Chosen Metrics for Fraud Detection:")
# print("- Precision: to minimize false positives (don't flag legitimate transactions)")
# print("- Recall: to catch as many fraud cases as possible")
# print("- F1-score: balances precision and recall")
# print("- ROC-AUC: evaluates discrimination across thresholds")
#
# """# Step 3: Calculate and Compare Metrics"""
#
# from sklearn.metrics import (
#     confusion_matrix,
#     classification_report,
#     roc_auc_score,
#     ConfusionMatrixDisplay
# )
#
# # Confusion matrix
# cm = confusion_matrix(y_test, y_pred)
# disp = ConfusionMatrixDisplay(confusion_matrix=cm)
# disp.plot(cmap='Blues')
# plt.title("Confusion Matrix")
# plt.show()
#
# # Classification report
# print(classification_report(y_test, y_pred, digits=4))
#
# # ROC-AUC
# roc_auc = roc_auc_score(y_test, y_proba)
# print(f"ROC-AUC Score: {roc_auc:.4f}")
#
# """# Step 4: Reflect on Model Improvement"""
#
# print("REFLECTION:")
# print("""
# - Precision is important to avoid annoying legitimate customers with false fraud alerts.
# - Recall is critical to catch actual fraud and minimize financial loss.
# - The F1-score provides a balanced view, and ROC-AUC gives threshold-independent insight.
#
# Improvement Strategies:
# - Use SMOTE or undersampling to address class imbalance.
# - Explore other classifiers like XGBoost or logistic regression with class_weight.
# - Adjust the decision threshold for optimal trade-off based on business cost analysis.
# """)
# ```

# %% [markdown]
# ## 🚀 Next Steps
# Upon completing this activity, you'll be ready to advance to more complex model implementation and evaluation tasks. Understanding and applying these metrics will empower you to make informed decisions throughout your machine learning projects.
