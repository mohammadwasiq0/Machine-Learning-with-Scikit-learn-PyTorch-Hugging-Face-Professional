# %% [markdown]
# # 👩‍💻 Apply Ensemble Learning to Your Project
#
# ## 📋 Overview
# In this activity, you will apply ensemble learning techniques to your machine learning models. Ensemble learning is a powerful approach that combines multiple models to improve predictive accuracy, stability, and robustness. This is crucial in tackling complex datasets and is widely used in various data-driven industries. By completing this activity, you'll strengthen your skills in building and optimizing machine learning models using bagging and boosting techniques.
#
# ## 🎯 Learning Outcomes
# By the end of this lab, you will be able to:
# - Implement ensemble learning techniques to enhance model accuracy and robustness
# - Compare the performance of ensemble models against baseline models using key metrics
# - Reflect on the practical improvements and challenges faced during implementation

# %% [markdown]
# ## Task 1: Review Your Dataset and Baseline Model
# You will start by revisiting one of your previous projects or choosing a new dataset. Ensure it has the complexity necessary for ensemble learning.
#
# <b>Reminder:</b> A number of dataset csv files have been uploaded to this lab environment. Choose one dataset from the following options:
# - Customer Churn (Telecom): `Telco-Customer-Churn.csv`
# - Credit Card Fraud Detection: `creditcard.csv`
# - Bike Sharing Demand Forecasting: `bikeshareday.csv`
# - IMDb Sentiment Analysis (NLP): `IMDB_Dataset.csv`
# - Customer Segmentation (Clustering): `marketing_campaign.csv`
#
# ### 💻 Code

# %%
# Load the dataset
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt 
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score, roc_curve
from sklearn.metrics import accuracy_score
from sklearn.model_selection import RandomizedSearchCV

import joblib

import warnings 
warnings.filterwarnings("ignore")
pd.set_option('display.max_columns', 10000)

# %%
# Load and prepare your data

# Load and prepare your data

# Your code here
df= pd.read_csv("creditcard.csv")

# Explore the data
print(f"Shape of Data: {df.shape}")
print("\n----- Top 5 Rows of Data ------")
display(df.head())
print("\n----- Information of Data ------")
print(df.info())
print("\n----- Summmary of Data ------")
display(df.describe(percentiles=[i/100 for i in range(0, 101) if i%5==0]).T)
print("\n------- Number of Null Values ---------")
print(df.isnull().sum())

print("Class Count:\n", df['Class'].value_counts(dropna=False))

print("Class distribution:\n", df['Class'].value_counts(dropna=False, normalize=True))
# Out:
# Shape of Data: (284807, 31)
#
# ----- Top 5 Rows of Data ------
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0  0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390 -0.311169
# 1  0.085102 -0.255425 -0.166974  1.612727  1.065235  0.489095 -0.143772
# 2  0.247676 -1.514654  0.207643  0.624501  0.066084  0.717293 -0.165946
# 3  0.377436 -1.387024 -0.054952 -0.226487  0.178228  0.507757 -0.287924
# 4 -0.270533  0.817739  0.753074 -0.822843  0.538196  1.345852 -1.119670
#
# ...

# %%
X = df.drop(columns=['Class'])  # Features
y = df['Class']                 # Target

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %% [markdown]
# ### 🔍 Practice
# 1. Analyze the baseline model and its metric performance.
# 2. Identify areas where predictions can be improved using ensemble techniques.
#
# ### ✅ Success Checklist
# - Baseline model performance reviewed
# - Areas for improvement identified
#
# ### 💡 Key Points
# - Understand the strengths and weaknesses of your baseline model.
# - Consider the dataset's complexity and variance.

# %% [markdown]
# ## Task 2: Implement a Bagging Technique (Random Forest)
# Utilize the Random Forest algorithm to enhance prediction accuracy by balancing variance.
#
# ### 💻 Code

# %%
# Implement a bagging technique

# Initialize and train Random Forest
rf_model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=42)
rf_model.fit(X_train, y_train)

# Evaluate performance
rf_predictions = rf_model.predict(X_test)
rf_accuracy = accuracy_score(y_test, rf_predictions)
print(f'Random Forest Accuracy: {rf_accuracy}')
# Out:
# Random Forest Accuracy: 0.9995084442259752

# %% [markdown]
# ### 🔍 Practice
# 1. Fine-tune hyperparameters for optimal model performance.
#
# ### ✅ Success Checklist
# - Random Forest model implemented
# - Hyperparameters fine-tuned

# %% [markdown]
# ## Task 3: Apply a Boosting Technique (XGBoost)
# Boost model accuracy using techniques like XGBoost while minimizing prediction errors.
#
# ### 💻 Code

# %%
# Apply a boosting technique

import xgboost as xgb
# Create DMatrix for XGBoost
dtrain = xgb.DMatrix(X_train, label=y_train)
dtest = xgb.DMatrix(X_test, label=y_test)

# Define parameters and train model
params = {'objective': 'binary:logistic', 'max_depth': 3, 'eta': 0.1}
xgb_model = xgb.train(params, dtrain, num_boost_round=100)

# Evaluate performance
xgb_predictions = xgb_model.predict(dtest)
xgb_accuracy = accuracy_score(y_test, [round(value) for value in xgb_predictions])
print(f'XGBoost Accuracy: {xgb_accuracy}')
# Out:
# XGBoost Accuracy: 0.9996313331694814

# %% [markdown]
# ### 🔍 Practice
# 1. Adjust parameters like learning rate and boosting rounds.
# 2. Test enhancements on accuracy and error reduction.
#
# ### ✅ Success Checklist
# - Boosting technique applied
# - Parameter tuning completed

# %% [markdown]
# ## Task 4: Evaluate Ensemble Models
# Compare the performance of ensemble models against your baseline using several evaluation metrics.
#
# ### 🔍 Practice
# 1. Analyze metrics such as accuracy, precision, recall, and F1-score.
# 2. Reflect on reduction in variance and bias.
#
# ### ✅ Success Checklist
# - Metrics compared between baseline and ensemble models
# - Observations about ensemble effect documented
#
# ### 💡 Key Points
# - Ensemble learning can significantly decrease variance and bias.
# - The choice of metrics can illuminate model differences.

# %% [markdown]
# ## Task 5: Reflect on Ensemble Learning Implementation
# Document your reflections on the ensemble learning application. Consider how each method contributed to improvements.
#
# ### 🔍 Practice
# 1. Note any challenges faced and solutions.
# 2. Describe which technique (bagging vs. boosting) offered the most benefit.

# %% [markdown]
# ## ❗ Common Mistakes to Avoid
# - Not fine-tuning hyperparameters based on dataset specifics
# - Ignoring the trade-offs between model complexity and interpretability
# - Focusing only on accuracy without considering other metrics

# %% [markdown]
# ## 📚 Exemplar Solution

# %% [markdown]
# <details>
#
# <summary><strong>Click HERE to see a reference solution</strong></summary>
#
# ```python
# # TASK 1
# # Example of dataset preparation
# import pandas as pd
# from sklearn.model_selection import train_test_split
#
# # Load dataset
# data = pd.read_csv('your_dataset.csv') # Replace with your dataset path
#
# # Split the data
# X_train, X_test, y_train, y_test = train_test_split(data.drop('target', axis=1), data['target'], test_size=0.3, random_state=42)
#
# # TASK 2
# from sklearn.ensemble import RandomForestClassifier
# from sklearn.metrics import accuracy_score
#
# # Note: Preprocessing steps may be required and will be unique depending on the dataset and model you are using
# # In this case we are simplifying our example by only looking at numeric variables
#
# # Initialize and train Random Forest
# rf_model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=42)
# rf_model.fit(X_train, y_train)
#
# # Evaluate performance
# rf_predictions = rf_model.predict(X_test)
# rf_accuracy = accuracy_score(y_test, rf_predictions)
# print(f'Random Forest Accuracy: {rf_accuracy}')
#
# # TASK 3
# import xgboost as xgb
# # Create DMatrix for XGBoost
# dtrain = xgb.DMatrix(X_train, label=y_train)
# dtest = xgb.DMatrix(X_test, label=y_test)
#
# # Define parameters and train model
# params = {'objective': 'binary:logistic', 'max_depth': 3, 'eta': 0.1}
# xgb_model = xgb.train(params, dtrain, num_boost_round=100)
#
# # Evaluate performance
# xgb_predictions = xgb_model.predict(dtest)
# xgb_accuracy = accuracy_score(y_test, [round(value) for value in xgb_predictions])
# print(f'XGBoost Accuracy: {xgb_accuracy}')
# ```

# %% [markdown]
# ## 🚀 Next Steps
# In the upcoming module, you will focus on model evaluation and interpretability. Understanding how to assess model performance using various metrics is crucial as you prepare to deploy models in a real-world environment.
