# %% [markdown]
# # Prepare Your Dataset for Modeling
#
# ## 📋 Overview
# In this activity, you'll preprocess a dataset to make it ready for machine learning modeling. You'll learn to clean, transform, and encode data, which are essential skills for data scientists and machine learning practitioners. This ensures your data is usable and consistent, which is critical for accurate model training and prediction.
#
# ## 🎯 Activity Goals
# By completing this activity, you will:
# - Utilize data preprocessing techniques to clean and prepare a dataset
# - Apply scaling, encoding, and feature selection methods to enhance data quality
# - Divide your data into training and testing sets for subsequent modeling
#
# ## 🌎 Scenario
# You are a data analyst at a technology company tasked with preparing a dataset for a predictive modeling project. The dataset, which you've used in prior learning, needs to be cleansed and transformed to ensure it is suitable for building robust machine learning models that can deliver actionable insights.
#
# <B>Reminder:</B> A number of dataset CSV files have been uploaded to this lab environment. Choose one dataset from the following options:
# - Customer Churn (Telecom): `Telco-Customer-Churn.csv`
# - Credit Card Fraud Detection: `creditcard.csv`
# - Bike Sharing Demand Forecasting: `bikeshareday.csv`
# - IMDb Sentiment Analysis (NLP): `IMDB_Dataset.csv`
# - Customer Segmentation (Clustering): `marketing_campaign.csv`

# %%
# Load the dataset
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt 
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import warnings 
warnings.filterwarnings("ignore")
pd.set_option('display.max_columns', 10000)

# %% [markdown]
# ## Step 1: Load and Explore the Dataset
# Select a dataset from previous activities. Load it using a tool like Pandas and perform a preliminary inspection to understand its structure.

# %%
# Your code here
df= pd.read_csv("creditcard.csv")

# Explore the data
print(f"Shape of Data: {df.shape}")
print("\n----- Top 5 Rows of Data ------")
display(df.head())
print("\n----- Information of Data ------")
print(df.info())
print("\n----- Summmary of Data ------")
display(df.describe(percentiles=[i/100 for i in range(0, 101) if i%5==0]).T)
print("\n------- Number of Null Values ---------")
print(df.isnull().sum())

print("Class Count:\n", df['Class'].value_counts(dropna=False))

print("Class distribution:\n", df['Class'].value_counts(dropna=False, normalize=True))
# Out:
# Shape of Data: (284807, 31)
#
# ----- Top 5 Rows of Data ------
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0  0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390 -0.311169
# 1  0.085102 -0.255425 -0.166974  1.612727  1.065235  0.489095 -0.143772
# 2  0.247676 -1.514654  0.207643  0.624501  0.066084  0.717293 -0.165946
# 3  0.377436 -1.387024 -0.054952 -0.226487  0.178228  0.507757 -0.287924
# 4 -0.270533  0.817739  0.753074 -0.822843  0.538196  1.345852 -1.119670
#
# ...

# %% [markdown]
# 💡 <B>Tip:</B> Use df.head() to quickly view the first few rows of your dataset.
#
# <B>❗ Common Mistakes</B>
# - Ignoring the dataset’s column types
# - Failing to initially check for basic inconsistencies
# - Overlooking null or missing values

# %% [markdown]
# ## Step 2: Handle Missing Data
# Identify missing values and decide whether to impute them using mean, median, or mode or to drop the affected rows/columns.

# %%
# Your code here
# Check for missing values
print("Missing values:\n", df.isnull().sum())  # No missing values expected
# Out:
# Missing values:
#  Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %% [markdown]
# 💡 <B>Tip:</B> Use df.info() to quickly find columns with missing values.

# %% [markdown]
# ## Step 3: Normalize or Scale Features
# Apply scaling techniques like Min-Max or Z-score normalization to ensure features are on a similar scale.

# %%
# Your code here

scaler = StandardScaler()
df['Amount_scaled'] = scaler.fit_transform(df[['Amount']])
df['Time_scaled'] = scaler.fit_transform(df[['Time']])

# Drop original 'Amount' and 'Time'
df.drop(['Amount', 'Time'], axis=1, inplace=True)

# %% [markdown]
# <b>💡 Tip:</b> Choose a method that fits the nature of your data; Min-Max for bounded features and standard scaling for others.

# %% [markdown]
# ## Step 4: Encode Categorical Variables
# Convert categorical variables into numerical values using one-hot or label encoding, depending on whether they are nominal or ordinal.

# %%
# Your code here

# There is no Categorical Variable

# %% [markdown]
# <b>💡 Tip:</b> Use one-hot encoding for nominal categories where order doesn't matter.

# %% [markdown]
# ## Step 5: Detect and Treat Outliers
# Use visualizations like box plots to spot outliers. Decide whether to remove them or transform those values.

# %%
# Your code here
# Visualize outliers in 'Amount_scaled'
sns.boxplot(x='Class', y='Amount_scaled', data=df)
plt.title("Boxplot of Transaction Amount by Class")
plt.show()

# %% [markdown]
# <b>💡 Tip: </b>Not all outliers are errors; consider their domain-driven significance.

# %% [markdown]
# ## Step 6: Select Features
# Employ feature selection techniques to focus on data attributes that are significant to your problem’s context.

# %%
# Your code here

# All features are anonymized and assumed relevant
X = df.drop('Class', axis=1)
y = df['Class']

# %% [markdown]
# <b>💡 Tip:</b> Use domain knowledge and exploratory data analysis to guide feature selection.

# %% [markdown]
# ## Step 7: Prepare the Dataset for Modeling
# Split the dataset into training and testing subsets. Aim for a typical split ratio (e.g., 70% training, 30% testing).

# %%
# Your code here

# Stratified split to maintain class balance
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)

print("Training set size:", X_train.shape)
print("Test set size:", X_test.shape)
# Out:
# Training set size: (199364, 30)
# Test set size: (85443, 30)

# %% [markdown]
# <b>💡 Tip:</b> Ensure your split accounts for class imbalances if present.

# %% [markdown]
# ## ✅ Success Checklist
# - Dataset is free of missing values or appropriate imputations made
# - Numerical features are properly scaled
# - Categorical data accurately encoded
# - Outliers documented and appropriately handled
# - Relevant features identified and retained
# - Dataset split into training and testing sets
#
# ## 💡 Key Points
# - Preprocessing is essential for reliable machine learning outcomes
# - Imputation, scaling, and encoding techniques can vary by data characteristics
# - Proper dataset splitting ensures model evaluation reliability

# %% [markdown]
# ## 📚 Exemplar Solution
# Here's how your prepared dataset should look: A clean, numeric, and scaled dataset with training and testing subsets ready for modeling. You might see reduced dimensionality if feature selection was aggressive. An exemplar solution is given below for the credit card fraud dataset.

# %% [markdown]
# <details>
#
# <summary><strong>Click HERE to see a reference solution</strong></summary>
#
# ```python
# # Credit Card Fraud Detection Preprocessing Pipeline
#
# # Step 1: Load and Explore the Dataset
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt
# import seaborn as sns
#
# from sklearn.preprocessing import StandardScaler
# from sklearn.model_selection import train_test_split
#
# # Load dataset
# df = pd.read_csv('creditcard.csv')
#
# # Initial exploration
# print("Shape:", df.shape)
# print(df.head())
# print(df.info())
# print(df.describe())
# print("Class distribution:\n", df['Class'].value_counts(normalize=True))
#
# # Step 2: Handle Missing Data
# # Check for missing values
# print("Missing values:\n", df.isnull().sum())  # No missing values expected
#
# # Step 3: Normalize or Scale Features
# # Scale 'Amount' and 'Time' features
# scaler = StandardScaler()
# df['Amount_scaled'] = scaler.fit_transform(df[['Amount']])
# df['Time_scaled'] = scaler.fit_transform(df[['Time']])
#
# # Drop original 'Amount' and 'Time'
# df.drop(['Amount', 'Time'], axis=1, inplace=True)
#
# # Step 4: Encode Categorical Variables
# # No categorical variables in this dataset — all are numerical
#
# # Step 5: Detect and Treat Outliers
# # Visualize outliers in 'Amount_scaled'
# sns.boxplot(x='Class', y='Amount_scaled', data=df)
# plt.title("Boxplot of Transaction Amount by Class")
# plt.show()
#
# # Decision: Retain all values as outliers may be informative for fraud
#
# # Step 6: Select Features
# # All features are anonymized and assumed relevant
# X = df.drop('Class', axis=1)
# y = df['Class']
#
# # Step 7: Prepare the Dataset for Modeling
# # Stratified split to maintain class balance
# X_train, X_test, y_train, y_test = train_test_split(
#     X, y, test_size=0.3, random_state=42, stratify=y
# )
#
# print("Training set size:", X_train.shape)
# print("Test set size:", X_test.shape)
# ```

# %% [markdown]
# ### How does your work compare?
# - Did you handle missing data and outliers proficiently?
# - Is your data well-scaled and encoded for the algorithms you intend to use?
# ## 🚀 Next Steps
# Having preprocessed your dataset, you're now ready to move on to modeling, where you'll learn to implement and evaluate models using this prepared data.
