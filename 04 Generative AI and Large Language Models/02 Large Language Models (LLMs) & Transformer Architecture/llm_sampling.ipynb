# %% [markdown]
# # **Experiment with LLM Sampling Parameters**
#
# **Time Estimate:** 40 minutes

# %% [markdown]
# ## **📋 Overview**
#
# In this activity, you'll explore and experiment with various sampling parameters in Large Language Models (LLMs) to understand their impact on text generation. You'll use the Hugging Face Transformers library to manipulate parameters such as temperature, top-p, and repetition penalty, allowing you to fine-tune model outputs for different applications. This skill is valuable for roles that require adapting AI model capabilities to diverse content creation needs such as content strategists and AI developers.

# %% [markdown]
# ## **🎯 Learning Outcomes**
#
# By the end of this lab, you will be able to:
#
# * Adjust temperature and top-p parameters in LLMs to influence text generation styles.
# * Analyze changes in output to determine appropriate parameter settings for different scenarios.

# %% [markdown]
# ## **Task 1: Environment Setup and Initial Exploration [15 minutes]**
#
# 1. Execute the code and ensure you can generate basic text outputs from the model.
# 2. Reflect: What do you observe in the default generated text?

# %%
# !pip install --upgrade --force-reinstall "numpy"
# !pip install --upgrade --force-reinstall "transformers"
# # If you need TensorFlow specifically:
# !pip install --upgrade --force-reinstall "tensorflow"

# !pip install --upgrade numpy
# !pip install --upgrade --force-reinstall transformers

# !pip install --upgrade torchvision torch

# %%
# from transformers import pipeline
# from transformers import pipelines
from transformers import pipeline

import numpy as np
# Load text generation pipeline with a pre-trained model
generator = pipelines('text-generation', model='gpt2')

# Example prompt
prompt = "The future of technology involves"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-223027859.py in <cell line: 0>()
#       5 import numpy as np
#       6 # Load text generation pipeline with a pre-trained model
# ----> 7 generator = pipelines('text-generation', model='gpt2')
#       8
#       9 # Example prompt
#
# TypeError: 'module' object is not callable

# %%
from transformers import pipeline
import numpy as np

# Load text generation pipeline with a pre-trained model
generator = pipeline('text-generation', model='gpt2')

# Example prompt
prompt = "The future of technology involves"
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Device set to use cuda:0

# %% [markdown]
# ### **✅ Success Checklist**
# * Basic generation with initial model
#
# ### **💡 Key Points**
#
# * Understand the default behavior of text generation models

# %% [markdown]
# ## **Task 2: Experiment with Temperature [10 minutes]**
#
# Explore how temperature settings affect the creativity and determinism of generated text.

# %%
# Adjust temperature setting
temperature_outputs = []
for temp in [0.2, 0.5, 0.9]:
    result = generator(prompt, max_length=50, num_return_sequences=1, temperature=temp)
    temperature_outputs.append(result)
# Out:
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)

# %%
# Different temperature settings to test
temperatures = [0.2, 0.5, 0.9]

# Store results
temperature_outputs = []

# Generate text for each temperature
for temp in temperatures:
    result = generator(
        prompt,
        max_length=50,
        num_return_sequences=1,
        temperature=temp
    )
    temperature_outputs.append(result)

# Print results neatly
for i, temp in enumerate(temperatures):
    print(f"\n--- Temperature: {temp} ---")
    print(temperature_outputs[i][0]['generated_text'])
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# --- Temperature: 0.2 ---
# The future of technology involves a shift in the way we think about the world.
#
# "We are seeing a shift in the way we think about the world," he said. "We are seeing a shift in the way we think about the world. We are seeing a shift in the way we think about the world. We are seeing a shift in the way we think about the world. We are seeing a shift in the way we think about the world."
#
# The shift in our thinking about the world is a shift in our thinking about the world.
#
# "We are seeing a shift in the way we think about the world. We are seeing a shift in the way we think about the world. We are seeing a shift in the way we think about the world. We are seeing a shift in the way we think about the world. We are seeing a shift in the way we think about the world. We are seeing a shift in the way we think about the world. We are seeing a shift in the way we think about the world. We are seeing a shift in the way we think about the world. We are seeing a shift in the way we think about the world. We are seeing a shift in the way we think about the world. We are seeing a shift
#
# --- Temperature: 0.5 ---
# The future of technology involves a new set of challenges.
#
# "We are entering a new era of innovation, and we need to develop the tools to make it work," said Mr. K. B. Kallos, the chief executive officer of the technology consulting firm. "This is an important part of our growth strategy."
#
# The new technology is called the new iPhone. The company has been working with Apple to develop the technology since 2012, and is working with Apple to implement the technology in its products.
#
# The iPhone will have a more advanced multitasking experience, which will allow users to create multi-tasking apps, including those that share information, view photos and view videos, according to a statement from Apple.
#
# The new technology will make it easier for people to multitask, and will allow people to share information about their lives, such as their jobs or schools, with others.
#
# Apple has been working with Apple on the new technology for several years, but it has not received a response from Apple, according to a person familiar with the matter.
#
# Apple is also working on a new, cheaper version of its iPhone, with a resolution that is about 1,000 times smaller than the iPhone 5S, the person said. It is expected to
#
# --- Temperature: 0.9 ---
# The future of technology involves getting rid of the power to manage the Internet and bring the Internet to people in ways that work across sectors of society.
#
# It is not enough to just make the system work on platforms such as smartphones. The internet could be a central platform to build the infrastructure to create the "Internet Age," where people will have more access to information. The system could also provide a better way to connect people and change their lives.
#
# The Internet was designed to be a way for companies to make money and create value for all of humanity. But it is not yet ready to become the platform the world needs.
#
# Today, there is an increasing number of people who are looking to start a business and be a part of a tech ecosystem. In fact, around 30 percent of the world's population is now living on the Internet, meaning that there are many people out there who live in a world where information is readily accessible and distributed.
#
# The people who are ready to bring that opportunity to the world are those working in the field of online companies and startups. In short, they are the people who want to make the new economy more sustainable, less dependent on big companies and more open to new ideas.
#
# What are the future of the Web of Things?

# %% [markdown]
# ### **✅ Success Checklist**
#
# * Clear understanding of temperature effects
# * Documented observations
#
# ### **💡 Key Points**
#
# * Understand the impact of temperature settings through exploration

# %% [markdown]
# ## **Task 3: Continue Experimentation with Top-p and Repetition Penalty [15 minutes]**
#
# * Use varying top-p settings to modify token selection constraints.
# * Implement repetition penalty adjustments to control redundancy in output sequences.

# %%
# Example for top-p with repetition penalty
advanced_outputs = []
params = {'top_k': [10, 30, 60], 'top_p': [0.9, 0.7, 0.5], 'repetition_penalty': [1.0, 2.0, 3.0]}
for k in params['top_k']:
    for p in params['top_p']:
        for rp in params['repetition_penalty']:
            result = generator(prompt, max_length=50, num_return_sequences=1, top_k=k, top_p=p, repetition_penalty=rp)
            advanced_outputs.append(result)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)

# %%
# Parameters to explore
top_k_values = [10, 30, 60]
top_p_values = [0.9, 0.7, 0.5]
repetition_penalties = [1.0, 2.0, 3.0]

# Store outputs
advanced_outputs = []

# Generate text for all parameter combinations
for k in top_k_values:
    for p in top_p_values:
        for rp in repetition_penalties:
            result = generator(
                prompt,
                max_length=50,
                num_return_sequences=1,
                top_k=k,
                top_p=p,
                repetition_penalty=rp
            )
            advanced_outputs.append({
                'top_k': k,
                'top_p': p,
                'repetition_penalty': rp,
                'text': result[0]['generated_text']
            })

# Print results neatly
for output in advanced_outputs:
    print(f"\n--- top_k: {output['top_k']}, top_p: {output['top_p']}, repetition_penalty: {output['repetition_penalty']} ---")
    print(output['text'])
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# --- top_k: 10, top_p: 0.9, repetition_penalty: 1.0 ---
# The future of technology involves the development of new technologies that are more efficient, more efficient, and more efficient, and that will be more efficient, efficient, and efficient.
#
# The future of technology involves the development of new technologies that are more efficient, more efficient, and more efficient, and that will be more efficient, efficient, and efficient. The future of technology involves the development of new technologies that are more efficient, more efficient, and more efficient, and that will be more efficient, efficient, and efficient. The future of technology involves the development of new technologies that are more efficient, more efficient, and more efficient, and that will be more efficient, efficient, and efficient.
#
# The future of technology involves the development of new technologies that are more efficient, more efficient, and more efficient, and that will be more efficient, efficient, and efficient. The future of technology involves the development of new technologies that are more efficient, more efficient, and more efficient, and that will be more efficient, efficient, and efficient. The future of technology involves the development of new technologies that are more efficient, more efficient, and more efficient, and that will be more efficient, efficient, and efficient.
#
# The future of technology involves the development of new technologies that are more efficient, more efficient
#
# --- top_k: 10, top_p: 0.9, repetition_penalty: 2.0 ---
# The future of technology involves more than just the internet. It also requires us to understand how our lives and work are being made, so that we can better use them in ways which benefit society as a whole."
#
#
# --- top_k: 10, top_p: 0.9, repetition_penalty: 3.0 ---
# The future of technology involves a shift in the way we interact with our surroundings. In this context, it is important to understand how technologies change as they become more pervasive and complex."
# : The new world has come into being thanks largely for advances such at Facebook that enable us all—the userbase on social media platforms like Twitter, Instagram or Google+ —to share information about what's happening around them via apps built by people who are also part-time employees working outside their home countries (see "Why You Should Never Leave Your Home Country"). We can't afford not sharing things online because there aren�t enough places available so those living abroad don`T have access; even if one could get some help from friends through WhatsApp app, where you'd be able sign up under your own name while still keeping track without having any direct contact info whatsoever. But then again, maybe someone might already know which country these contacts live? That would make an excellent tool!
#
# --- top_k: 10, top_p: 0.7, repetition_penalty: 1.0 ---
# The future of technology involves a new kind of innovation, one that will make it possible for people to create and share their own digital content.
#
# The next generation of digital content will be created by people who have the skills, experience and knowledge to create content that is unique to them.
#
# This is the future of digital content.
#
# The next generation of digital content will be created by people who have the skills, experience and knowledge to create content that is unique to them.
#
# The next generation of digital content will be created by people who have the skills, experience and knowledge to create content that is unique to them.
#
# The next generation of digital content will be created by people who have the skills, experience and knowledge to create content that is unique to them.
#
# The next generation of digital content will be created by people who have the skills, experience and knowledge to create content that is unique to them.
#
# The next generation of digital content will be created by people who have the skills, experience and knowledge to create content that is unique to them.
#
# The next generation of digital content will be created by people who have the skills, experience and knowledge to create content that is unique to them.
#
# The next generation of digital content will be created by people
#
# --- top_k: 10, top_p: 0.7, repetition_penalty: 2.0 ---
# The future of technology involves a new and exciting way to make money.
# "We're looking at how we can use our existing technologies, like the cloud," he said. "But there's also another aspect that will be interesting: what kind or who are you going after? And this is where it gets really tricky."
#
# --- top_k: 10, top_p: 0.7, repetition_penalty: 3.0 ---
# The future of technology involves a new and exciting way to communicate with one another.
# , the first generation computer is capable only in terms that are suitable for human use; it can be used by anyone who wants an understanding about what's going on at home or abroad as well (and perhaps even more importantly), but not just those living under its own roof."
#
# --- top_k: 10, top_p: 0.5, repetition_penalty: 1.0 ---
# The future of technology involves a new way of thinking about the world. The future of technology is not a new one. It is a new way of thinking about the world.
#
# The future of technology involves a new way of thinking about the world. The future of technology is not a new one. It is a new way of thinking about the world.
#
# The future of technology involves a new way of thinking about the world. The future of technology is not a new one. It is a new way of thinking about the world.
#
# The future of technology involves a new way of thinking about the world. The future of technology is not a new one. It is a new way of thinking about the world.
#
# The future of technology involves a new way of thinking about the world. The future of technology is not a new one. It is a new way of thinking about the world.
#
# The future of technology involves a new way of thinking about the world. The future of technology is not a new one. It is a new way of thinking about the world.
#
# The future of technology involves a new way of thinking about the world. The future of technology is not a new one. It is a new way of thinking about the world.
#
# The future
#
# --- top_k: 10, top_p: 0.5, repetition_penalty: 2.0 ---
# The future of technology involves the development and deployment, maintenance and repair by all parties involved in a project.
#
#
# --- top_k: 10, top_p: 0.5, repetition_penalty: 3.0 ---
# The future of technology involves the development and deployment, maintenance and enhancement of new technologies.
#
#
# --- top_k: 30, top_p: 0.9, repetition_penalty: 1.0 ---
# The future of technology involves more than just technology. It involves a new way of thinking about the world. And the future of technology is not just about the future of technology. It's about the future of technology in general.
#
# I'm not a scientist. I'm not a politician. I'm not a business person. I'm not a lawyer. I'm not a journalist. I'm not a scientist. I'm not a lawyer. I'm not a journalist. I'm not a journalist. I'm not a lawyer. I'm not a lawyer. I'm not a journalist. I'm not a lawyer. I'm not a journalist. I'm not a lawyer. I'm not a lawyer. I'm not a lawyer. I'm not a lawyer. I'm not a lawyer. I'm not a lawyer. I'm not a lawyer. I'm not a lawyer. I'm not a lawyer. I'm not a lawyer.
#
# So, I'm not a scientist. I'm not a politician. I'm not a lawyer. I'm not a lawyer. I'm not a lawyer. I'm not a lawyer. I'm not a lawyer. I'm not a lawyer. I'm not a lawyer. I'm not a lawyer. I'm not a lawyer
#
# --- top_k: 30, top_p: 0.9, repetition_penalty: 2.0 ---
# The future of technology involves a new kind and different types of innovation.
# - The Future Is Here, by Mark Twain (1839) is one example: In his book 'My Life', he describes the history that took place in 1829 when we first discovered how to build houses from scratch using simple tools such as wood or metal parts for roofing; it was this knowledge which led him into designing buildings on all continents through various stages at least until 1901 – not only because these were very difficult but also due largely directly related inventions like fireplaces invented during World War I.[1] At some point back then many people believed there would be no need with computers yet they knew about building wooden bridges without making them outfitted up so you could use your hands rather than being tied down after an attack etc.,[2][3]. As more information emerged online over time however things got much simpler where everything went straight forward instead becoming something else entirely! There are still times though what's happening today seems quite unusual - especially now even if most ideas come before 1900 can happen just around 20 years later...
#
#  "I've seen great progress since 1890s." But really? This has always been my favourite quote ever written... It doesn't say anything bad here either [4]: http://www9x7
#
# --- top_k: 30, top_p: 0.9, repetition_penalty: 3.0 ---
# The future of technology involves more than the cost, but also a new kind.
# : The most important question that can be asked is this : What does it mean for us to have freedom? For instance if we live in an economy where all our activities are done online or by phone then how do you think your privacy will change when these things become possible? I believe such questions should not go unanswered. There has been much discussion about what digital rights would look like after free speech and other freedoms come into being (see section 3)
#
# --- top_k: 30, top_p: 0.7, repetition_penalty: 1.0 ---
# The future of technology involves the development of new technologies, and new technologies are often developed at a faster pace than previously imagined. In order to understand the nature of these new technologies, it is important to understand the underlying mechanisms that drive them.
#
# A key characteristic of new technologies is the ability to adapt to new conditions and to adapt to new environments. This is achieved through the ability to develop new technologies, and to adapt to new environments.
#
# The first and most important factor in the development of new technologies is the ability to adapt to new conditions and to adapt to new environments. This is achieved through the ability to develop new technologies, and to adapt to new environments.
#
# In order to understand the mechanisms that drive new technologies, it is important to understand the underlying mechanisms that drive them.
#
# The development of new technologies is a process of gradual and gradual changes. The development of new technologies is a process of gradual and gradual changes.
#
# The development of new technologies is a process of gradual and gradual changes.
#
# In order to understand the mechanisms that drive new technologies, it is important to understand the underlying mechanisms that drive them.
#
# The development of new technologies is a process of gradual and gradual changes.
#
# The development of new technologies is a process of gradual and
#
# --- top_k: 30, top_p: 0.7, repetition_penalty: 2.0 ---
# The future of technology involves the development and deployment, in particular for mobile devices such as smartphones.
# "There are a number trends that we need to look at," he said on Thursday during an event with Google's global headquarters here."We have seen how rapidly phones can become ubiquitous by 2020 but there is still much work ahead if it continues like this or not: We will see more smartphone apps developed over time – some very fast ones (like those used today), others less so".
#
# --- top_k: 30, top_p: 0.7, repetition_penalty: 3.0 ---
# The future of technology involves making it easier to find, track and control the Internet.
#  (Photo: The Associated Press) Story Highlights Apple's iPhone 7 Plus is expected on sale this fall in a limited number at select stores nationwide
# (AP Photo/Carolyn Kaster), 2nd UPDATE Jan 8th 2017 : A few days ago we reported that an upcoming new version will include support for Google Glass 3, which was developed by Microsoft as part from scratch but has been delayed due not only because its specs are different than those found inside existing Android devices such Asha & Samsung smartphones; however there have also already be rumors about how many people could use these glasses with their own handsets if they wanted them today. We now know what kind device would fit into your pocket - one you can wear without any additional electronics or accessories like sunglasses etc.. If so then I am sure most consumers who buy my latest phone might want something similar too! In addition our sources tell us "It looks good" when worn under clothing though some users claim otherwise...I'm still waiting until next year before buying another smartphone :)
#
# --- top_k: 30, top_p: 0.5, repetition_penalty: 1.0 ---
# The future of technology involves a shift away from the traditional "technology of the past" to a new "technology of the future."
#
# "The future of technology involves a shift away from the traditional "technology of the past" to a new "technology of the future."
#
# The future of technology is a new kind of "technology of the future."
#
# The future of technology is a new kind of "technology of the future."
#
# The future of technology is a new kind of "technology of the future."
#
# The future of technology is a new kind of "technology of the future."
#
# The future of technology is a new kind of "technology of the future."
#
# The future of technology is a new kind of "technology of the future."
#
# The future of technology is a new kind of "technology of the future."
#
# The future of technology is a new kind of "technology of the future."
#
# The future of technology is a new kind of "technology of the future."
#
# The future of technology is a new kind of "technology of the future."
#
# The future of technology is a new kind of "technology of the future."
#
# The future of technology is a new kind of "technology of the future."
#
#
#
# --- top_k: 30, top_p: 0.5, repetition_penalty: 2.0 ---
# The future of technology involves a shift away from the "smart" and more traditional ways that we use our smartphones.
#
#
# --- top_k: 30, top_p: 0.5, repetition_penalty: 3.0 ---
# The future of technology involves the development and use by individuals, organizations or governments to improve their own capabilities.
# - The United States government has a long history in this area with respect for its role as an international partner on global security issues including nuclear proliferation; it is also recognized that such cooperation can lead toward greater military strength through better coordination among nations' intelligence agencies (see "UNAIDS: A New Role"). However there are many other factors which may contribute significantly towards achieving these goals if we continue our efforts at building up bilateral ties between countries concerned about terrorism prevention/response capability while simultaneously supporting UPA's work against terrorist financing activities within those groups who have been identified using sophisticated means like cyberattacks." - US Department Of State http://www1ststatesecuritypolicyreviews2ndhandbook4thedition5_3rdparty6a9c8b0f7d89e35bbbeae0914efbcaf15
#
# --- top_k: 60, top_p: 0.9, repetition_penalty: 1.0 ---
# The future of technology involves the development of new technologies and the development of new technologies that improve the lives of people. The use of technology to improve human health, health and wellbeing is not something that we should be afraid to take on."
#
# Mr Lee, who is the chairman of the European Commission, said: "The use of technology for good will is not something that we should be afraid to take on.
#
# "We should be willing to invest in research and development that is designed to improve human health, health and wellbeing and that is what is needed in this century.
#
# "The use of technology for good will is not something that we should be afraid to take on. We should be willing to invest in research and development that is designed to improve human health, health and wellbeing and that is what is needed in this century."
#
# Image copyright Getty Images Image caption The European Commission is hoping to get its hands on some of the £100m worth of data it is seeking
#
# The European Commission is hoping to get its hands on some of the £100m worth of data it is seeking.
#
# The data will be used to test new technologies to tackle the problem of obesity and diabetes.
#
# The European Commission hopes the data will help it to develop a "super
#
# --- top_k: 60, top_p: 0.9, repetition_penalty: 2.0 ---
# The future of technology involves a range in which the world's largest economies will compete with each other, and where we need to be better able to innovate.
#  I'm not going down that path here – this is simply about what happens when you get right into business.'
#
# --- top_k: 60, top_p: 0.9, repetition_penalty: 3.0 ---
# The future of technology involves the development and use in many ways by people who have not yet achieved a certain level. There is no doubt that our work can be applied to other fields such as medicine, physics or biology; we do so because there are some significant advances being made today which will enable us – at least for now - and possibly tomorrow's generations too."
#
#
# --- top_k: 60, top_p: 0.7, repetition_penalty: 1.0 ---
# The future of technology involves the development of new technologies that are not only faster and more reliable, but also provide more security and protection. The future of the Internet is in the hands of people who are willing to spend their money and time to protect their privacy and privacy rights.
#
# The Internet is a free and open platform that allows anyone to create, share, and modify any form of content. The Internet is a free and open platform that allows anyone to create, share, and modify any form of content.
#
# The Internet is a free and open platform that allows anyone to create, share, and modify any form of content.
#
# The Internet is a free and open platform that allows anyone to create, share, and modify any form of content.
#
# The Internet is a free and open platform that allows anyone to create, share, and modify any form of content.
#
# The Internet is a free and open platform that allows anyone to create, share, and modify any form of content.
#
# The Internet is a free and open platform that allows anyone to create, share, and modify any form of content.
#
# The Internet is a free and open platform that allows anyone to create, share, and modify any form of content.
#
# The Internet is a free and
#
# --- top_k: 60, top_p: 0.7, repetition_penalty: 2.0 ---
# The future of technology involves the creation and use by people, institutions or groups to make a difference. It is often argued that technological change will lead to greater innovation in our lives rather than just more money for us all."
# - From The Economist: "In fact there are now two major global tech companies with strong business ties – Google (GOOGL) and Facebook Inc. - which have been trying since 2007...and where they've done well on both fronts but remain struggling financially as investors seek higher returns from their businesses".
#
# --- top_k: 60, top_p: 0.7, repetition_penalty: 3.0 ---
# The future of technology involves a shift in the way people interact with it. The more we understand how to use digital technologies, and thus our ability for self-expression on social media platforms like Facebook, Twitter or YouTube — where users can share their own content without fear that others will view them as an insult – then they'll be able better communicate what's happening online than ever before."
#  (Image: Flickr)
#
# --- top_k: 60, top_p: 0.5, repetition_penalty: 1.0 ---
# The future of technology involves a lot of things.
#
# "I think the future of technology is going to be about more than just the next generation of computers. It's going to be about the next generation of people. And that's going to be a lot of things. It's going to be about the future of technology. And that's going to be about the future of people."
#
# He said that the next generation of computers will be based on "the next generation of computers."
#
# "We're going to be able to do things that are not possible in the past. We're going to be able to do things that are not possible in the past. And that's going to be a lot of things. It's going to be about the future of technology."
#
# He said that the next generation of computers will be based on "the next generation of computers."
#
# "We're going to be able to do things that are not possible in the past. We're going to be able to do things that are not possible in the past. And that's going to be a lot of things. It's going to be about the future of technology."
#
# He said that the next generation of computers will be based on "the next generation of computers."
#
#
# --- top_k: 60, top_p: 0.5, repetition_penalty: 2.0 ---
# The future of technology involves the development and deployment, in large part through new technologies such as artificial intelligence (AI), robotics or other intelligent systems.
#
#
# --- top_k: 60, top_p: 0.5, repetition_penalty: 3.0 ---
# The future of technology involves the development and deployment, as well.

# %% [markdown]
# ### **✅ Success Checklist**
#
# * Completed multiple experiments with different parameters
# * In-depth analysis documented
#
# ### **💡 Key Points**
#
# * Understand varying top-p and repitition penalty through experimentation

# %% [markdown]
# ## **❗ Common Mistakes to Avoid**
#
# * Overlook adjusting too many parameters simultaneously: It may complicate understanding.
# * Focusing on only one type of output: Explore various scenarios for balanced insights.

# %% [markdown]
# ## **🚀 Next Steps**
#
# Advance your skills by exploring how these parameters are used in real-world AI applications or by tuning parameters for industry-specific tasks, enhancing both creative and procedural text generation capabilities.

# %% [markdown]
# ## **📋Exemplar Solution**
# <details>
# <summary><strong>
# Click HERE to see an exemplar solution
# </summary></strong>
#
# ### **Task 2 Solution**
#
# Reflect on the varied creative outputs based on temperature:
#
# * **Temperature 0.2**: Consistent and predictable, ideal for factual presentations.
#
# ### **Task 3 Solution**
#
# * **Top-p 0.9**: Reduced choices ensure more focused content, great for clarity-driven tasks.
# </details>
