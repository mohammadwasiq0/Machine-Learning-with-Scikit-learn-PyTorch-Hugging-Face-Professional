# %% [markdown]
# # 👩‍💻 Grid, Random, or Bayesian? Tune and Compare Your Models
#
# ## 📋 Overview
# This activity challenges you to implement and compare three distinct hyperparameter tuning techniques: Grid Search, Random Search, and Bayesian Optimization. By the end, you’ll have a hands-on understanding of how each method operates, its strengths and limitations, and where it might be best applied. You'll experience firsthand how these techniques impact model performance across different datasets, helping you make informed decisions in your future machine learning projects.
#
# ## 🎯 Learning Outcomes
# By the end of this lab, you will be able to:
#
# - ✅ Implement and compare Grid Search, Random Search, and Bayesian Optimization for hyperparameter tuning
# - ✅ Evaluate the effectiveness of different tuning methods using performance metrics
# - ✅ Make informed decisions on which hyperparameter tuning method to use in various scenarios

# %% [markdown]
# ## Task 1: Dataset Selection and Preprocessing
#
# **Context:** Proper dataset selection and preprocessing ensures the data is clean and ready for modeling.
#
# **Steps:**
#
# 1. Ensure the dataset is preprocessed: handle missing data, normalize features as needed, and split into training and testing sets.

# %%
# Import libraries
# Task 1: Dataset Selection and Preprocessing
# Load and preprocess dataset

from sklearn.model_selection import train_test_split, GridSearchCV, RandomizedSearchCV
from sklearn.datasets import load_iris
from sklearn.ensemble import RandomForestClassifier
import numpy as np
import optuna
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler    


# Task 1: Load and preprocess dataset
iris = load_iris()

# Splitting data
X_train, X_test, y_train, y_test = train_test_split(iris.data, iris.target, test_size=0.3, random_state=42)

# Impute missing values (if any) with the mean of each column
imputer = SimpleImputer(strategy='mean')
X_train = imputer.fit_transform(X_train)
X_test = imputer.transform(X_test)

# Handle feature scaling using StandardScaler
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# 💡 **Tip:** Use `train_test_split` from `sklearn.model_selection` for data splitting.
#
# ⚙️ **Test Your Work:**
# - The dataset should show the features and corresponding labels, demonstrating the preprocessing steps.

# %% [markdown]
# ## Task 2: Implementing Grid Search
#
# **Context:** Grid Search involves exhaustively searching through a predefined hyperparameter grid.
#
# **Steps:**
#
# 1. Set up a hyperparameter grid for a Random Forest model.
# 2. Use `GridSearchCV` from scikit-learn to carry out the grid search.
# 3. Record the best parameters along with performance metrics like accuracy.

# %%
# Task 2: Implementing Grid Search

param_grid = {'n_estimators': [50, 100, 200], 'max_depth': [None, 10, 20], 'min_samples_split': [2, 5, 10]}
grid_search = GridSearchCV(estimator=RandomForestClassifier(), param_grid=param_grid, cv=5, verbose=2)
grid_search.fit(X_train, y_train)
grid_best_params = grid_search.best_params_
grid_accuracy = accuracy_score(y_test, grid_search.best_estimator_.predict(X_test))
# Out:
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# [CV] END max_depth=None, min_samples_split=2, n_estimators=50; total time=   0.1s
# [CV] END max_depth=None, min_samples_split=2, n_estimators=50; total time=   0.1s
# [CV] END max_depth=None, min_samples_split=2, n_estimators=50; total time=   0.1s
# [CV] END max_depth=None, min_samples_split=2, n_estimators=50; total time=   0.1s
# [CV] END max_depth=None, min_samples_split=2, n_estimators=50; total time=   0.1s
# [CV] END max_depth=None, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=None, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=None, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=None, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=None, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=None, min_samples_split=2, n_estimators=200; total time=   0.2s
# [CV] END max_depth=None, min_samples_split=2, n_estimators=200; total time=   0.3s
# [CV] END max_depth=None, min_samples_split=2, n_estimators=200; total time=   0.2s
# [CV] END max_depth=None, min_samples_split=2, n_estimators=200; total time=   0.2s
# [CV] END max_depth=None, min_samples_split=2, n_estimators=200; total time=   0.3s
# [CV] END max_depth=None, min_samples_split=5, n_estimators=50; total time=   0.1s
# [CV] END max_depth=None, min_samples_split=5, n_estimators=50; total time=   0.1s
# [CV] END max_depth=None, min_samples_split=5, n_estimators=50; total time=   0.1s
# [CV] END max_depth=None, min_samples_split=5, n_estimators=50; total time=   0.1s
# [CV] END max_depth=None, min_samples_split=5, n_estimators=50; total time=   0.1s
# [CV] END max_depth=None, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END max_depth=None, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END max_depth=None, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END max_depth=None, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END max_depth=None, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END max_depth=None, min_samples_split=5, n_estimators=200; total time=   0.2s
# [CV] END max_depth=None, min_samples_split=5, n_estimators=200; total time=   0.2s
# [CV] END max_depth=None, min_samples_split=5, n_estimators=200; total time=   0.2s
# [CV] END max_depth=None, min_samples_split=5, n_estimators=200; total time=   0.2s
# [CV] END max_depth=None, min_samples_split=5, n_estimators=200; total time=   0.2s
# [CV] END max_depth=None, min_samples_split=10, n_estimators=50; total time=   0.1s
# [CV] END max_depth=None, min_samples_split=10, n_estimators=50; total time=   0.1s
# [CV] END max_depth=None, min_samples_split=10, n_estimators=50; total time=   0.1s
# [CV] END max_depth=None, min_samples_split=10, n_estimators=50; total time=   0.1s
# [CV] END max_depth=None, min_samples_split=10, n_estimators=50; total time=   0.1s
# [CV] END max_depth=None, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=None, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=None, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=None, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=None, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=None, min_samples_split=10, n_estimators=200; total time=   0.3s
# [CV] END max_depth=None, min_samples_split=10, n_estimators=200; total time=   0.3s
# [CV] END max_depth=None, min_samples_split=10, n_estimators=200; total time=   0.2s
# [CV] END max_depth=None, min_samples_split=10, n_estimators=200; total time=   0.2s
# [CV] END max_depth=None, min_samples_split=10, n_estimators=200; total time=   0.3s
# [CV] END .max_depth=10, min_samples_split=2, n_estimators=50; total time=   0.1s
# [CV] END .max_depth=10, min_samples_split=2, n_estimators=50; total time=   0.1s
# [CV] END .max_depth=10, min_samples_split=2, n_estimators=50; total time=   0.1s
# [CV] END .max_depth=10, min_samples_split=2, n_estimators=50; total time=   0.1s
# [CV] END .max_depth=10, min_samples_split=2, n_estimators=50; total time=   0.1s
# [CV] END max_depth=10, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=10, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=10, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=10, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=10, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=10, min_samples_split=2, n_estimators=200; total time=   0.2s
# [CV] END max_depth=10, min_samples_split=2, n_estimators=200; total time=   0.2s
# [CV] END max_depth=10, min_samples_split=2, n_estimators=200; total time=   0.2s
# [CV] END max_depth=10, min_samples_split=2, n_estimators=200; total time=   0.2s
# [CV] END max_depth=10, min_samples_split=2, n_estimators=200; total time=   0.2s
# [CV] END .max_depth=10, min_samples_split=5, n_estimators=50; total time=   0.1s
# [CV] END .max_depth=10, min_samples_split=5, n_estimators=50; total time=   0.1s
# [CV] END .max_depth=10, min_samples_split=5, n_estimators=50; total time=   0.1s
# [CV] END .max_depth=10, min_samples_split=5, n_estimators=50; total time=   0.1s
# [CV] END .max_depth=10, min_samples_split=5, n_estimators=50; total time=   0.1s
# [CV] END max_depth=10, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END max_depth=10, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END max_depth=10, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END max_depth=10, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END max_depth=10, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END max_depth=10, min_samples_split=5, n_estimators=200; total time=   0.2s
# [CV] END max_depth=10, min_samples_split=5, n_estimators=200; total time=   0.2s
# [CV] END max_depth=10, min_samples_split=5, n_estimators=200; total time=   0.2s
# [CV] END max_depth=10, min_samples_split=5, n_estimators=200; total time=   0.2s
# [CV] END max_depth=10, min_samples_split=5, n_estimators=200; total time=   0.2s
# [CV] END max_depth=10, min_samples_split=10, n_estimators=50; total time=   0.1s
# [CV] END max_depth=10, min_samples_split=10, n_estimators=50; total time=   0.1s
# [CV] END max_depth=10, min_samples_split=10, n_estimators=50; total time=   0.1s
# [CV] END max_depth=10, min_samples_split=10, n_estimators=50; total time=   0.1s
# [CV] END max_depth=10, min_samples_split=10, n_estimators=50; total time=   0.1s
# [CV] END max_depth=10, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=10, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=10, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=10, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=10, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=10, min_samples_split=10, n_estimators=200; total time=   0.2s
# [CV] END max_depth=10, min_samples_split=10, n_estimators=200; total time=   0.2s
# [CV] END max_depth=10, min_samples_split=10, n_estimators=200; total time=   0.2s
# [CV] END max_depth=10, min_samples_split=10, n_estimators=200; total time=   0.2s
# [CV] END max_depth=10, min_samples_split=10, n_estimators=200; total time=   0.2s
# [CV] END .max_depth=20, min_samples_split=2, n_estimators=50; total time=   0.1s
# [CV] END .max_depth=20, min_samples_split=2, n_estimators=50; total time=   0.1s
# [CV] END .max_depth=20, min_samples_split=2, n_estimators=50; total time=   0.1s
# [CV] END .max_depth=20, min_samples_split=2, n_estimators=50; total time=   0.1s
# [CV] END .max_depth=20, min_samples_split=2, n_estimators=50; total time=   0.1s
# [CV] END max_depth=20, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=20, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=20, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=20, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=20, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=20, min_samples_split=2, n_estimators=200; total time=   0.2s
# [CV] END max_depth=20, min_samples_split=2, n_estimators=200; total time=   0.2s
# [CV] END max_depth=20, min_samples_split=2, n_estimators=200; total time=   0.2s
# [CV] END max_depth=20, min_samples_split=2, n_estimators=200; total time=   0.2s
# [CV] END max_depth=20, min_samples_split=2, n_estimators=200; total time=   0.2s
# [CV] END .max_depth=20, min_samples_split=5, n_estimators=50; total time=   0.1s
# [CV] END .max_depth=20, min_samples_split=5, n_estimators=50; total time=   0.1s
# [CV] END .max_depth=20, min_samples_split=5, n_estimators=50; total time=   0.1s
# [CV] END .max_depth=20, min_samples_split=5, n_estimators=50; total time=   0.1s
# [CV] END .max_depth=20, min_samples_split=5, n_estimators=50; total time=   0.1s
# [CV] END max_depth=20, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END max_depth=20, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END max_depth=20, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END max_depth=20, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END max_depth=20, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END max_depth=20, min_samples_split=5, n_estimators=200; total time=   0.2s
# [CV] END max_depth=20, min_samples_split=5, n_estimators=200; total time=   0.2s
# [CV] END max_depth=20, min_samples_split=5, n_estimators=200; total time=   0.2s
# [CV] END max_depth=20, min_samples_split=5, n_estimators=200; total time=   0.2s
# [CV] END max_depth=20, min_samples_split=5, n_estimators=200; total time=   0.2s
# [CV] END max_depth=20, min_samples_split=10, n_estimators=50; total time=   0.1s
# [CV] END max_depth=20, min_samples_split=10, n_estimators=50; total time=   0.1s
# [CV] END max_depth=20, min_samples_split=10, n_estimators=50; total time=   0.1s
# [CV] END max_depth=20, min_samples_split=10, n_estimators=50; total time=   0.1s
# [CV] END max_depth=20, min_samples_split=10, n_estimators=50; total time=   0.1s
# [CV] END max_depth=20, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=20, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=20, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=20, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=20, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=20, min_samples_split=10, n_estimators=200; total time=   0.2s
# [CV] END max_depth=20, min_samples_split=10, n_estimators=200; total time=   0.2s
# [CV] END max_depth=20, min_samples_split=10, n_estimators=200; total time=   0.2s
# [CV] END max_depth=20, min_samples_split=10, n_estimators=200; total time=   0.2s
# [CV] END max_depth=20, min_samples_split=10, n_estimators=200; total time=   0.2s

# %% [markdown]
# 💡 **Tip:** Define a comprehensive grid for key hyperparameters.
#
# ⚙️ **Test Your Work:**
# - Plots should clearly show the relationship between actual and predicted values for the best model from Grid Search. Legends - should correctly identify each data series in the plot.

# %% [markdown]
# ## Task 3: Applying Random Search
#
# **Context:** Random Search involves sampling hyperparameters randomly from a defined space.
#
# **Steps:**
#
# 1. Configure a random search space for the same Random Forest model.
# 2. Implement `RandomizedSearchCV` to sample configurations and carry out the search.
# 3. Record the best parameters along with performance metrics.

# %%
# Task 3: Applying Random Search

param_distributions = {'n_estimators': np.arange(50, 200, 50), 'max_depth': [None, 10, 20], 'min_samples_split': np.arange(2, 11)}
random_search = RandomizedSearchCV(estimator=RandomForestClassifier(), param_distributions=param_distributions, n_iter=10, cv=5, verbose=2, random_state=42)
random_search.fit(X_train, y_train)
random_best_params = random_search.best_params_
random_accuracy = accuracy_score(y_test, random_search.best_estimator_.predict(X_test))
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END .max_depth=10, min_samples_split=3, n_estimators=50; total time=   0.1s
# [CV] END .max_depth=10, min_samples_split=3, n_estimators=50; total time=   0.1s
# [CV] END .max_depth=10, min_samples_split=3, n_estimators=50; total time=   0.1s
# [CV] END .max_depth=10, min_samples_split=3, n_estimators=50; total time=   0.1s
# [CV] END .max_depth=10, min_samples_split=3, n_estimators=50; total time=   0.1s
# [CV] END max_depth=None, min_samples_split=2, n_estimators=50; total time=   0.1s
# [CV] END max_depth=None, min_samples_split=2, n_estimators=50; total time=   0.1s
# [CV] END max_depth=None, min_samples_split=2, n_estimators=50; total time=   0.1s
# [CV] END max_depth=None, min_samples_split=2, n_estimators=50; total time=   0.1s
# [CV] END max_depth=None, min_samples_split=2, n_estimators=50; total time=   0.1s
# [CV] END max_depth=None, min_samples_split=9, n_estimators=100; total time=   0.1s
# [CV] END max_depth=None, min_samples_split=9, n_estimators=100; total time=   0.1s
# [CV] END max_depth=None, min_samples_split=9, n_estimators=100; total time=   0.1s
# [CV] END max_depth=None, min_samples_split=9, n_estimators=100; total time=   0.1s
# [CV] END max_depth=None, min_samples_split=9, n_estimators=100; total time=   0.1s
# [CV] END max_depth=10, min_samples_split=3, n_estimators=100; total time=   0.1s
# [CV] END max_depth=10, min_samples_split=3, n_estimators=100; total time=   0.1s
# [CV] END max_depth=10, min_samples_split=3, n_estimators=100; total time=   0.1s
# [CV] END max_depth=10, min_samples_split=3, n_estimators=100; total time=   0.1s
# [CV] END max_depth=10, min_samples_split=3, n_estimators=100; total time=   0.1s
# [CV] END max_depth=None, min_samples_split=8, n_estimators=50; total time=   0.1s
# [CV] END max_depth=None, min_samples_split=8, n_estimators=50; total time=   0.1s
# [CV] END max_depth=None, min_samples_split=8, n_estimators=50; total time=   0.1s
# [CV] END max_depth=None, min_samples_split=8, n_estimators=50; total time=   0.1s
# [CV] END max_depth=None, min_samples_split=8, n_estimators=50; total time=   0.1s
# [CV] END max_depth=10, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=10, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=10, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=10, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=10, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=None, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END max_depth=None, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END max_depth=None, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END max_depth=None, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END max_depth=None, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END max_depth=20, min_samples_split=7, n_estimators=100; total time=   0.1s
# [CV] END max_depth=20, min_samples_split=7, n_estimators=100; total time=   0.1s
# [CV] END max_depth=20, min_samples_split=7, n_estimators=100; total time=   0.1s
# [CV] END max_depth=20, min_samples_split=7, n_estimators=100; total time=   0.1s
# [CV] END max_depth=20, min_samples_split=7, n_estimators=100; total time=   0.1s
# [CV] END max_depth=None, min_samples_split=3, n_estimators=100; total time=   0.1s
# [CV] END max_depth=None, min_samples_split=3, n_estimators=100; total time=   0.1s
# [CV] END max_depth=None, min_samples_split=3, n_estimators=100; total time=   0.1s
# [CV] END max_depth=None, min_samples_split=3, n_estimators=100; total time=   0.1s
# [CV] END max_depth=None, min_samples_split=3, n_estimators=100; total time=   0.1s
# [CV] END max_depth=None, min_samples_split=6, n_estimators=50; total time=   0.1s
# [CV] END max_depth=None, min_samples_split=6, n_estimators=50; total time=   0.1s
# [CV] END max_depth=None, min_samples_split=6, n_estimators=50; total time=   0.1s
# [CV] END max_depth=None, min_samples_split=6, n_estimators=50; total time=   0.1s
# [CV] END max_depth=None, min_samples_split=6, n_estimators=50; total time=   0.1s

# %% [markdown]
# 💡 **Tip:** Ensure the random search space is broad and varied.
#
# ⚙️ **Test Your Work:**
# - Plots should clearly show the relationship between actual and predicted values for the best model from Random Search. Legends should correctly identify each data series in the plot.

# %% [markdown]
# ## Task 4: Exploring Bayesian Optimization
#
# **Context:** Bayesian Optimization iteratively focuses on promising hyperparameter configurations.
#
# **Steps:**
#
# 1. Utilize a tool like `optuna` to apply Bayesian Optimization for the Random Forest model's hyperparameters.
# 2. Observe and document how Bayesian Optimization iteratively improves the configurations.
# 3. Record the best parameters along with performance metrics.

# %%
# Task 4: Exploring Bayesian Optimization

def objective(trial):
    n_estimators = trial.suggest_int('n_estimators', 50, 200)
    max_depth = trial.suggest_int('max_depth', 5, 30)
    min_samples_split = trial.suggest_int('min_samples_split', 2, 10)
    model = RandomForestClassifier(n_estimators=n_estimators, max_depth=max_depth, min_samples_split=min_samples_split)
    score = np.mean(cross_val_score(model, X_train, y_train, cv=3))
    return score

study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=50)
bayesian_best_params = study.best_params
model = RandomForestClassifier(**study.best_params)
model.fit(X_train, y_train)
bayesian_accuracy = accuracy_score(y_test, model.predict(X_test))
# Out:
# [I 2025-09-25 09:52:49,897] A new study created in memory with name: no-name-fb7c0309-99d4-409f-ad8f-64ae048265f7
# [I 2025-09-25 09:52:50,281] Trial 0 finished with value: 0.942857142857143 and parameters: {'n_estimators': 107, 'max_depth': 29, 'min_samples_split': 10}. Best is trial 0 with value: 0.942857142857143.
# [I 2025-09-25 09:52:50,645] Trial 1 finished with value: 0.9333333333333332 and parameters: {'n_estimators': 83, 'max_depth': 13, 'min_samples_split': 10}. Best is trial 0 with value: 0.942857142857143.
# [I 2025-09-25 09:52:51,036] Trial 2 finished with value: 0.942857142857143 and parameters: {'n_estimators': 114, 'max_depth': 11, 'min_samples_split': 5}. Best is trial 0 with value: 0.942857142857143.
# [I 2025-09-25 09:52:51,493] Trial 3 finished with value: 0.9333333333333332 and parameters: {'n_estimators': 131, 'max_depth': 18, 'min_samples_split': 3}. Best is trial 0 with value: 0.942857142857143.
# [I 2025-09-25 09:52:51,923] Trial 4 finished with value: 0.9333333333333332 and parameters: {'n_estimators': 124, 'max_depth': 10, 'min_samples_split': 3}. Best is trial 0 with value: 0.942857142857143.
# [I 2025-09-25 09:52:52,294] Trial 5 finished with value: 0.942857142857143 and parameters: {'n_estimators': 106, 'max_depth': 7, 'min_samples_split': 4}. Best is trial 0 with value: 0.942857142857143.
# [I 2025-09-25 09:52:52,941] Trial 6 finished with value: 0.9238095238095237 and parameters: {'n_estimators': 189, 'max_depth': 5, 'min_samples_split': 3}. Best is trial 0 with value: 0.942857142857143.
# [I 2025-09-25 09:52:53,268] Trial 7 finished with value: 0.9238095238095237 and parameters: {'n_estimators': 95, 'max_depth': 5, 'min_samples_split': 4}. Best is trial 0 with value: 0.942857142857143.
# [I 2025-09-25 09:52:53,761] Trial 8 finished with value: 0.942857142857143 and parameters: {'n_estimators': 145, 'max_depth': 28, 'min_samples_split': 4}. Best is trial 0 with value: 0.942857142857143.
# [I 2025-09-25 09:52:54,330] Trial 9 finished with value: 0.942857142857143 and parameters: {'n_estimators': 159, 'max_depth': 10, 'min_samples_split': 5}. Best is trial 0 with value: 0.942857142857143.
# [I 2025-09-25 09:52:54,591] Trial 10 finished with value: 0.942857142857143 and parameters: {'n_estimators': 51, 'max_depth': 30, 'min_samples_split': 10}. Best is trial 0 with value: 0.942857142857143.
# [I 2025-09-25 09:52:54,857] Trial 11 finished with value: 0.9333333333333332 and parameters: {'n_estimators': 69, 'max_depth': 21, 'min_samples_split': 7}. Best is trial 0 with value: 0.942857142857143.
# [I 2025-09-25 09:52:55,275] Trial 12 finished with value: 0.9523809523809524 and parameters: {'n_estimators': 108, 'max_depth': 24, 'min_samples_split': 7}. Best is trial 12 with value: 0.9523809523809524.
# [I 2025-09-25 09:52:55,874] Trial 13 finished with value: 0.9333333333333332 and parameters: {'n_estimators': 166, 'max_depth': 25, 'min_samples_split': 8}. Best is trial 12 with value: 0.9523809523809524.
# [I 2025-09-25 09:52:56,186] Trial 14 finished with value: 0.9523809523809524 and parameters: {'n_estimators': 85, 'max_depth': 24, 'min_samples_split': 9}. Best is trial 12 with value: 0.9523809523809524.
# [I 2025-09-25 09:52:56,468] Trial 15 finished with value: 0.9333333333333332 and parameters: {'n_estimators': 77, 'max_depth': 23, 'min_samples_split': 8}. Best is trial 12 with value: 0.9523809523809524.
# [I 2025-09-25 09:52:56,682] Trial 16 finished with value: 0.9333333333333332 and parameters: {'n_estimators': 55, 'max_depth': 18, 'min_samples_split': 8}. Best is trial 12 with value: 0.9523809523809524.
# [I 2025-09-25 09:52:57,008] Trial 17 finished with value: 0.9523809523809524 and parameters: {'n_estimators': 88, 'max_depth': 25, 'min_samples_split': 7}. Best is trial 12 with value: 0.9523809523809524.
# [I 2025-09-25 09:52:57,471] Trial 18 finished with value: 0.942857142857143 and parameters: {'n_estimators': 127, 'max_depth': 21, 'min_samples_split': 9}. Best is trial 12 with value: 0.9523809523809524.
# [I 2025-09-25 09:52:57,733] Trial 19 finished with value: 0.9333333333333332 and parameters: {'n_estimators': 69, 'max_depth': 15, 'min_samples_split': 6}. Best is trial 12 with value: 0.9523809523809524.
# [I 2025-09-25 09:52:58,091] Trial 20 finished with value: 0.942857142857143 and parameters: {'n_estimators': 97, 'max_depth': 26, 'min_samples_split': 9}. Best is trial 12 with value: 0.9523809523809524.
# [I 2025-09-25 09:52:58,428] Trial 21 finished with value: 0.9333333333333332 and parameters: {'n_estimators': 93, 'max_depth': 24, 'min_samples_split': 7}. Best is trial 12 with value: 0.9523809523809524.
# [I 2025-09-25 09:52:58,753] Trial 22 finished with value: 0.942857142857143 and parameters: {'n_estimators': 87, 'max_depth': 22, 'min_samples_split': 7}. Best is trial 12 with value: 0.9523809523809524.
# [I 2025-09-25 09:52:59,031] Trial 23 finished with value: 0.942857142857143 and parameters: {'n_estimators': 68, 'max_depth': 27, 'min_samples_split': 6}. Best is trial 12 with value: 0.9523809523809524.
# [I 2025-09-25 09:52:59,446] Trial 24 finished with value: 0.9333333333333332 and parameters: {'n_estimators': 114, 'max_depth': 20, 'min_samples_split': 9}. Best is trial 12 with value: 0.9523809523809524.
# [I 2025-09-25 09:52:59,835] Trial 25 finished with value: 0.942857142857143 and parameters: {'n_estimators': 103, 'max_depth': 25, 'min_samples_split': 7}. Best is trial 12 with value: 0.9523809523809524.
# [I 2025-09-25 09:53:00,366] Trial 26 finished with value: 0.942857142857143 and parameters: {'n_estimators': 141, 'max_depth': 16, 'min_samples_split': 8}. Best is trial 12 with value: 0.9523809523809524.
# [I 2025-09-25 09:53:00,698] Trial 27 finished with value: 0.9333333333333332 and parameters: {'n_estimators': 86, 'max_depth': 27, 'min_samples_split': 6}. Best is trial 12 with value: 0.9523809523809524.
# [I 2025-09-25 09:53:00,993] Trial 28 finished with value: 0.9333333333333332 and parameters: {'n_estimators': 77, 'max_depth': 19, 'min_samples_split': 9}. Best is trial 12 with value: 0.9523809523809524.
# [I 2025-09-25 09:53:01,411] Trial 29 finished with value: 0.942857142857143 and parameters: {'n_estimators': 115, 'max_depth': 29, 'min_samples_split': 10}. Best is trial 12 with value: 0.9523809523809524.
# [I 2025-09-25 09:53:01,666] Trial 30 finished with value: 0.942857142857143 and parameters: {'n_estimators': 65, 'max_depth': 23, 'min_samples_split': 2}. Best is trial 12 with value: 0.9523809523809524.
# [I 2025-09-25 09:53:02,037] Trial 31 finished with value: 0.942857142857143 and parameters: {'n_estimators': 103, 'max_depth': 30, 'min_samples_split': 10}. Best is trial 12 with value: 0.9523809523809524.
# [I 2025-09-25 09:53:02,350] Trial 32 finished with value: 0.9333333333333332 and parameters: {'n_estimators': 84, 'max_depth': 28, 'min_samples_split': 10}. Best is trial 12 with value: 0.9523809523809524.
# [I 2025-09-25 09:53:02,782] Trial 33 finished with value: 0.9523809523809524 and parameters: {'n_estimators': 121, 'max_depth': 25, 'min_samples_split': 9}. Best is trial 12 with value: 0.9523809523809524.
# [I 2025-09-25 09:53:03,278] Trial 34 finished with value: 0.942857142857143 and parameters: {'n_estimators': 140, 'max_depth': 24, 'min_samples_split': 8}. Best is trial 12 with value: 0.9523809523809524.
# [I 2025-09-25 09:53:03,716] Trial 35 finished with value: 0.9333333333333332 and parameters: {'n_estimators': 121, 'max_depth': 26, 'min_samples_split': 5}. Best is trial 12 with value: 0.9523809523809524.
# [I 2025-09-25 09:53:04,133] Trial 36 finished with value: 0.9333333333333332 and parameters: {'n_estimators': 113, 'max_depth': 22, 'min_samples_split': 9}. Best is trial 12 with value: 0.9523809523809524.
# [I 2025-09-25 09:53:04,631] Trial 37 finished with value: 0.942857142857143 and parameters: {'n_estimators': 133, 'max_depth': 25, 'min_samples_split': 7}. Best is trial 12 with value: 0.9523809523809524.
# [I 2025-09-25 09:53:05,005] Trial 38 finished with value: 0.942857142857143 and parameters: {'n_estimators': 94, 'max_depth': 16, 'min_samples_split': 8}. Best is trial 12 with value: 0.9523809523809524.
# [I 2025-09-25 09:53:05,735] Trial 39 finished with value: 0.942857142857143 and parameters: {'n_estimators': 196, 'max_depth': 23, 'min_samples_split': 6}. Best is trial 12 with value: 0.9523809523809524.
# [I 2025-09-25 09:53:06,127] Trial 40 finished with value: 0.942857142857143 and parameters: {'n_estimators': 105, 'max_depth': 12, 'min_samples_split': 9}. Best is trial 12 with value: 0.9523809523809524.
# [I 2025-09-25 09:53:06,573] Trial 41 finished with value: 0.9333333333333332 and parameters: {'n_estimators': 120, 'max_depth': 28, 'min_samples_split': 10}. Best is trial 12 with value: 0.9523809523809524.
# [I 2025-09-25 09:53:07,152] Trial 42 finished with value: 0.942857142857143 and parameters: {'n_estimators': 154, 'max_depth': 27, 'min_samples_split': 10}. Best is trial 12 with value: 0.9523809523809524.
# [I 2025-09-25 09:53:07,453] Trial 43 finished with value: 0.9523809523809524 and parameters: {'n_estimators': 78, 'max_depth': 29, 'min_samples_split': 9}. Best is trial 12 with value: 0.9523809523809524.
# [I 2025-09-25 09:53:07,755] Trial 44 finished with value: 0.9523809523809524 and parameters: {'n_estimators': 76, 'max_depth': 29, 'min_samples_split': 9}. Best is trial 12 with value: 0.9523809523809524.
# [I 2025-09-25 09:53:07,982] Trial 45 finished with value: 0.9333333333333332 and parameters: {'n_estimators': 60, 'max_depth': 26, 'min_samples_split': 8}. Best is trial 12 with value: 0.9523809523809524.
# [I 2025-09-25 09:53:08,353] Trial 46 finished with value: 0.9523809523809524 and parameters: {'n_estimators': 98, 'max_depth': 24, 'min_samples_split': 7}. Best is trial 12 with value: 0.9523809523809524.
# [I 2025-09-25 09:53:08,692] Trial 47 finished with value: 0.9523809523809524 and parameters: {'n_estimators': 89, 'max_depth': 20, 'min_samples_split': 8}. Best is trial 12 with value: 0.9523809523809524.
# [I 2025-09-25 09:53:08,992] Trial 48 finished with value: 0.9523809523809524 and parameters: {'n_estimators': 78, 'max_depth': 30, 'min_samples_split': 5}. Best is trial 12 with value: 0.9523809523809524.
# [I 2025-09-25 09:53:09,618] Trial 49 finished with value: 0.942857142857143 and parameters: {'n_estimators': 176, 'max_depth': 22, 'min_samples_split': 9}. Best is trial 12 with value: 0.9523809523809524.

# %% [markdown]
# 💡 **Tip:** Define an objective function for `optuna` to optimize.
#
# ⚙️ **Test Your Work:**
# - Plots should clearly show the relationship between actual and predicted values for the best model from Bayesian Optimization. Legends should correctly identify each data series in the plot.

# %% [markdown]
# ## Task 5: Comparing Approaches and Performance
#
# **Context:** Comparing results helps evaluate the strengths and weaknesses of different hyperparameter tuning methods.
#
# **Steps:**
#
# 1. Systematically compare the results from Grid Search, Random Search, and Bayesian Optimization.
# 2. Reflect on key aspects such as speed, accuracy, and computational cost.

# %%
# Task 5: Comparing Approaches and Performance

print(f"Grid Search Best Parameters: {grid_best_params}, Accuracy: {grid_accuracy}")
print(f"Random Search Best Parameters: {random_best_params}, Accuracy: {random_accuracy}")
print(f"Bayesian Optimization Best Parameters: {bayesian_best_params}, Accuracy: {bayesian_accuracy}")
# Out:
# Grid Search Best Parameters: {'max_depth': 10, 'min_samples_split': 5, 'n_estimators': 50}, Accuracy: 1.0
# Random Search Best Parameters: {'n_estimators': 50, 'min_samples_split': 3, 'max_depth': 10}, Accuracy: 1.0
# Bayesian Optimization Best Parameters: {'n_estimators': 108, 'max_depth': 24, 'min_samples_split': 7}, Accuracy: 1.0

# %% [markdown]
# 💡 **Tip:** Use visualizations or statistical summaries to aid comparison.
#
# ⚙️ **Test Your Work:**
# - Plots should clearly illustrate the performance comparison between Grid Search, Random Search, and Bayesian Optimization. Legends should correctly identify the tuning method and corresponding performance metrics.

# %% [markdown]
# ### ✅ Success Checklist
#
# - Successfully selected and preprocessed the dataset
# - Implemented and tuned hyperparameters using Grid Search, Random Search, and Bayesian Optimization
# - Compared and analyzed results from the three tuning methods
# - Provided reflections and recommendations based on findings
#
# ### 🔍 Common Issues & Solutions
#
# **Problem:** Dataset not loading correctly.
# **Solution:** Verify the data source and ensure proper loading using pandas.
#
# **Problem:** Hyperparameter tuning errors.
# **Solution:** Check the parameter grid and search space to ensure compatibility with the chosen model.
#
# **Problem:** Bayesian Optimization not providing good results.
# **Solution:** Verify the objective function and optimization setup, and try increasing the number of trials.
#
# ### 🔑 Key Points
#
# - Grid Search exhaustively searches through predefined hyperparameter combinations.
# - Random Search samples hyperparameter configurations randomly and can be more time-efficient.
# - Bayesian Optimization iteratively focuses on promising configurations to refine performance.
# - Comparing different tuning methods helps understand their strengths, weaknesses, and suitable applications.

# %% [markdown]
# ## 💻 Exemplar Solution

# %% [markdown]
# <details>
# <summary><strong>Click HERE to see an exemplar solution</strong></summary>
#
# ```python
# from sklearn.model_selection import train_test_split, GridSearchCV, RandomizedSearchCV
# from sklearn.datasets import load_iris
# from sklearn.ensemble import RandomForestClassifier
# import numpy as np
# import optuna
# from sklearn.metrics import accuracy_score
# from sklearn.model_selection import cross_val_score
# from sklearn.impute import SimpleImputer
# from sklearn.preprocessing import StandardScaler
#
#
# # Task 1: Load and preprocess dataset
# iris = load_iris()
#
# # Splitting data
# X_train, X_test, y_train, y_test = train_test_split(iris.data, iris.target, test_size=0.3, random_state=42)
#
# # Impute missing values (if any) with the mean of each column
# imputer = SimpleImputer(strategy='mean')
# X_train = imputer.fit_transform(X_train)
# X_test = imputer.transform(X_test)
#
# # Handle feature scaling using StandardScaler
# scaler = StandardScaler()
# X_train = scaler.fit_transform(X_train)
# X_test = scaler.transform(X_test)
#
# # Task 2: Grid Search
# param_grid = {'n_estimators': [50, 100, 200], 'max_depth': [None, 10, 20], 'min_samples_split': [2, 5, 10]}
# grid_search = GridSearchCV(estimator=RandomForestClassifier(), param_grid=param_grid, cv=5, verbose=2)
# grid_search.fit(X_train, y_train)
# grid_best_params = grid_search.best_params_
# grid_accuracy = accuracy_score(y_test, grid_search.best_estimator_.predict(X_test))
#
# # Task 3: Random Search
# param_distributions = {'n_estimators': np.arange(50, 200, 50), 'max_depth': [None, 10, 20], 'min_samples_split': np.arange(2, 11)}
# random_search = RandomizedSearchCV(estimator=RandomForestClassifier(), param_distributions=param_distributions, n_iter=10, cv=5, verbose=2, random_state=42)
# random_search.fit(X_train, y_train)
# random_best_params = random_search.best_params_
# random_accuracy = accuracy_score(y_test, random_search.best_estimator_.predict(X_test))
#
# # Task 4: Bayesian Optimization using Optuna
# def objective(trial):
#     n_estimators = trial.suggest_int('n_estimators', 50, 200)
#     max_depth = trial.suggest_int('max_depth', 5, 30)
#     min_samples_split = trial.suggest_int('min_samples_split', 2, 10)
#     model = RandomForestClassifier(n_estimators=n_estimators, max_depth=max_depth, min_samples_split=min_samples_split)
#     score = np.mean(cross_val_score(model, X_train, y_train, cv=3))
#     return score
#
# study = optuna.create_study(direction='maximize')
# study.optimize(objective, n_trials=50)
# bayesian_best_params = study.best_params
# model = RandomForestClassifier(**study.best_params)
# model.fit(X_train, y_train)
# bayesian_accuracy = accuracy_score(y_test, model.predict(X_test))
#
# # Task 5:Comparing Approaches and Performance
# print(f"Grid Search Best Parameters: {grid_best_params}, Accuracy: {grid_accuracy}")
# print(f"Random Search Best Parameters: {random_best_params}, Accuracy: {random_accuracy}")
# print(f"Bayesian Optimization Best Parameters: {bayesian_best_params}, Accuracy: {bayesian_accuracy}")
# ```
